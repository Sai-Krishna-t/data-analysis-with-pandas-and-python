# %% [markdown]
# # Input and Output
# - The `read_csv` function supports dozens of parameters for handling various file formats.
# - All datasets are in the `io_examples` folder.

# %%
import pandas as pd

# %% [markdown]
# - Some datasets may not have a header column. Pandas will treat the first row as the colum names.
# - Passing `header=None` creates a numeric index for the columns.
# - The `names` parameter can set custom column names.

# %%
pd.read_csv('io_examples/sensor_data.csv')
# Out:
#    2024-01-15 06:00  22.1  45.3
# 0  2024-01-15 07:00  21.8  46.1
# 1  2024-01-15 08:00  23.4  44.0
# 2  2024-01-15 09:00  25.0  42.7
# 3  2024-01-15 10:00  26.3  41.2
# 4  2024-01-15 11:00  27.8  39.8
# 5  2024-01-15 12:00  28.5  38.5

# %%
pd.read_csv('io_examples/sensor_data.csv', header=None, names=['timestamp', 'temp','humidity'])
# Out:
#           timestamp  temp  humidity
# 0  2024-01-15 06:00  22.1      45.3
# 1  2024-01-15 07:00  21.8      46.1
# 2  2024-01-15 08:00  23.4      44.0
# 3  2024-01-15 09:00  25.0      42.7
# 4  2024-01-15 10:00  26.3      41.2
# 5  2024-01-15 11:00  27.8      39.8
# 6  2024-01-15 12:00  28.5      38.5

# %% [markdown]
# - Datasets may have comments or blank lines before the actual data.
# - The `skiprows` parameter skips a specified number of lines at the top of the file.

# %%
pd.read_csv('io_examples/quarterly_report.csv')
# Out:
#   Acme Corp — Quarterly Sales Report Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0              Generated: 2024-01-20        NaN        NaN        NaN
# 1          Contact: reports@acme.com        NaN        NaN        NaN
# 2                             Region         Q1         Q2         Q3
# 3                              North      52000      61000      58000
# 4                              South      48000      53000      55000
# 5                               East      61000      59000      64000
# 6                               West      45000      50000      52000
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2         Q4
# 3      73000
# 4      62000
# 5      71000
# 6      68000

# %%
pd.read_csv('io_examples/quarterly_report.csv', skiprows=3) # skips 3 rows
# Out:
#   Region     Q1     Q2     Q3     Q4
# 0  North  52000  61000  58000  73000
# 1  South  48000  53000  55000  62000
# 2   East  61000  59000  64000  71000
# 3   West  45000  50000  52000  68000

# %% [markdown]
# - By default, pandas recognizes common missing-value markers like `NaN`, `NA`, and empty strings.
# - Use `na_values` to define additional values that qualify as missing values.

# %%
pd.read_csv('io_examples/customer_data.csv')
# Out:
#             name      age  zipcode satisfaction referral_source
# 0  Alice Johnson       34     2134            9          Google
# 1      Bob Smith       --    10001            7          Friend
# 2    Carol White       28    90210      missing       Instagram
# 3      David Lee       45      501            8             NaN
# 4     Emma Davis  missing    60601           10          Google
# 5   Frank Miller       52    30301           --         Twitter
# 6      Grace Kim       29     2134            6          Friend
# 7     Henry Chen       41    10002          NaN              --

# %% [markdown]
# - The `dtype` parameter sets column types on import.
# - The dataset loses the leading zeroes for the `zipcode` column (like `00501`). Conversion later can't help.
# - Pass the `dtype` parameter a dictionary with column names as keys and data types as values.

# %%
cus = pd.read_csv('io_examples/customer_data.csv', 
                  na_values=["--", "missing"],
                 dtype={'zipcode': str})# assigns NaN to values mentioned in na_values
cus
# Out:
#             name   age zipcode  satisfaction referral_source
# 0  Alice Johnson  34.0   02134           9.0          Google
# 1      Bob Smith   NaN   10001           7.0          Friend
# 2    Carol White  28.0   90210           NaN       Instagram
# 3      David Lee  45.0   00501           8.0             NaN
# 4     Emma Davis   NaN   60601          10.0          Google
# 5   Frank Miller  52.0   30301           NaN         Twitter
# 6      Grace Kim  29.0   02134           6.0          Friend
# 7     Henry Chen  41.0   10002           NaN             NaN

# %% [markdown]
# - The `nrows` parameter imports only the first `n` rows.
# - The parameter can preview a large dataset without loading the complete filev into memory.
# - The `index_col` parameter sets a column's values as the index labels.

# %%
pd.read_csv('fortune1000.csv', nrows=100)
# Out:
#     Rank                   Company       Sector  \
# 0      1                   Walmart    Retailing
# 1      2               Exxon Mobil       Energy
# 2      3                     Apple   Technology
# 3      4        Berkshire Hathaway   Financials
# 4      5                  McKesson  Health Care
# ..   ...                       ...          ...
# 95    96  Twenty-First Century Fox        Media
# 96    97                     Deere  Industrials
# 97    98                    Tesoro       Energy
# 98    99               Time Warner        Media
# 99   100       Northwestern Mutual   Financials
#
#                                     Industry  Revenue  Profits  Employees
# 0                      General Merchandisers   482130    14694    2300000
# 1                         Petroleum Refining   246204    16150      75600
# 2                Computers, Office Equipment   233715    53394     110000
# 3   Insurance: Property and Casualty (Stock)   210821    24083     331000
# ...

# %%
pd.read_csv('fortune1000.csv', nrows=100, index_col='Rank')
# Out:
#                        Company       Sector  \
# Rank
# 1                      Walmart    Retailing
# 2                  Exxon Mobil       Energy
# 3                        Apple   Technology
# 4           Berkshire Hathaway   Financials
# 5                     McKesson  Health Care
# ...                        ...          ...
# 96    Twenty-First Century Fox        Media
# 97                       Deere  Industrials
# 98                      Tesoro       Energy
# 99                 Time Warner        Media
# 100        Northwestern Mutual   Financials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# 2                           Petroleum Refining   246204    16150      75600
# 3                  Computers, Office Equipment   233715    53394     110000
# 4     Insurance: Property and Casualty (Stock)   210821    24083     331000
# ...

# %% [markdown]
# ## Export DataFrame to CSV File
# - The `to_csv` method exports a `DataFrame` to a CSV file.
# - Its first argument is the filename.
# - By default, pandas will include the index. Set the `index` parameter to False to exclude the index.
# - The `columns` parameter limits the exported columns.

# %%
url = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"

# %%
baby_names = pd.read_csv(url)
baby_names.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2021  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 1           2021  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 2           2021  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# 3           2021  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 4           2021  FEMALE  ASIAN AND PACIFIC ISLANDER                Ava
#
#    Count  Rank
# 0     71     1
# 1     71     1
# 2     66     2
# 3     59     3
# 4     53     4

# %%
for column in ["Gender", "Ethnicity", "Child's First Name"]:
    baby_names[column] = baby_names[column].str.strip().str.upper()

# %%
baby_names
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2021  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 1               2021  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 2               2021  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 3               2021  FEMALE  ASIAN AND PACIFIC ISLANDER                MIA
# 4               2021  FEMALE  ASIAN AND PACIFIC ISLANDER                AVA
# ...              ...     ...                         ...                ...
# 29680           2012    MALE              BLACK NON HISP             CAYDEN
# 29681           2013  FEMALE          WHITE NON HISPANIC           MARGARET
# 29682           2013  FEMALE          WHITE NON HISPANIC              TAMAR
# 29683           2013  FEMALE          WHITE NON HISPANIC             AMANDA
# 29684           2012  FEMALE                    HISPANIC               ANNA
#
#        Count  Rank
# 0         71     1
# ...

# %%
baby_names.to_csv(path_or_buf='baby_names.csv') # by default includes index as well use index=False to not include index
baby_names.to_csv(path_or_buf='baby_names.csv', index=False) # if run again, overwrites the data

# %%
for column in ["Gender", "Ethnicity", "Child's First Name"]:
    baby_names[column] = baby_names[column].str.strip().str.title()

baby_names.head()
    


# '''mode : {'w', 'x', 'a'}, default 'w'
#     Forwarded to either `open(mode=)` or `fsspec.open(mode=)` to control
#     the file opening. Typical values include:

#     - 'w', truncate the file first.
#     - 'x', exclusive creation, failing if the file already exists.
#     - 'a', append to the end of file if it exists.'''
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2021  Female  Asian And Pacific Islander              Chloe
# 1           2021  Female  Asian And Pacific Islander             Olivia
# 2           2021  Female  Asian And Pacific Islander               Emma
# 3           2021  Female  Asian And Pacific Islander                Mia
# 4           2021  Female  Asian And Pacific Islander                Ava
#
#    Count  Rank
# 0     71     1
# 1     71     1
# 2     66     2
# 3     59     3
# 4     53     4

# %%
baby_names.to_csv(path_or_buf='baby_names.csv', index=False, columns=['Year of Birth', "Child's First Name", "Count"])

# %% [markdown]
# ## Import Excel Workbook into pandas
# - The `read_excel` function reads an Excel file/workbook into a `DataFrame`.

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://anu9rng:****@rb-artifactory.bosch.com/artifactory/api/pypi/python-virtual/simple
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
pd.read_excel('Data - Single Worksheet.xlsx')
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %% [markdown]
# - Use the `sheet_name` parameter if the workbook contains multiple worksheets.
# - Pass a single worksheet name or a list of worksheet names/index positions.
# - Pandas will store multiple worksheets in a Python dictionary.
# - The keys will be the worksheet names, and the values will be the `DataFrame` objects.

# %%
pd.read_excel('Data - Multiple Worksheets.xlsx')
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name='Data 1')
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name='Data 2')
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name=0)
pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name=1)
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
sheet = pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name=[0,1])
sheet = pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name=['Data 1', 'Data 2'])
type(sheet)
sheet
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %%
print(sheet['Data 1'])
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %% [markdown]
# - Pass the `sheet_name` parameter an argument of `None` to include all worksheets.
# - The `keys` method on a dictionary returns a collection of its keys.
# - The `values` method on a dictionary returns a collection of its values.

# %%
data = pd.read_excel('Data - Multiple Worksheets.xlsx', sheet_name=None)
data
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %%
data.keys()
# Out:
# dict_keys(['Data 1', 'Data 2'])

# %%
data['Data 1']
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
# can concat dataframes
pd.concat(data.values())
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
pd.concat(data.values(), ignore_index=True)
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F
# 5     Parker     Power        Raleigh      F
# 6    Preston  Prescott   Philadelphia      F
# 7    Ronaldo   Donaldo         Bangor      M
# 8      Megan   Stiller  San Francisco      M
# 9     Bustin    Jieber         Austin      F

# %% [markdown]
# ## Export Excel Workbook from pandas
# - The `read_excel` function writes a `DataFrame` to an Excel workbook.
# - By default, the worksheet name will be `Sheet1`.
# - The `sheet_name` parameter customizes the worksheet name.
# - By default, pandas will keep the index as a column. Set `index=False` to exclude the index.
# - The `columns` parameter limits the columns that pandas will write.

# %%
url = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"
baby_names = pd.read_csv(url)
baby_names.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2021  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 1           2021  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 2           2021  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# 3           2021  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 4           2021  FEMALE  ASIAN AND PACIFIC ISLANDER                Ava
#
#    Count  Rank
# 0     71     1
# 1     71     1
# 2     66     2
# 3     59     3
# 4     53     4

# %%
males = baby_names[baby_names['Gender'] == 'MALE']
females = baby_names[baby_names['Gender'] == 'FEMALE']

# %%
females.to_csv('NYC baby Data.csv')
females.to_excel('NYC baby Data.xlsx', index=False)
females.to_excel('NYC baby Data.xlsx', index=False, sheet_name='Females')
females.to_excel('NYC baby Data.xlsx', index=False, sheet_name='Females', columns=['Year of Birth', "Child's First Name", "Count"])

# %% [markdown]
# - The `ExcelWriter` class writes one or more `DataFrame` objects to an Excel file.
# - Use a context manager (the `with` keyword) in combination with the `ExcelWriter` object and an assigned variable.
# - Invoke the `to_excel` method on every `DataFrame` to include in the Excel workbook and pass in the `ExcelWriter` object as the first argument.
# - The `to_excel` method supports `sheet_name`, `index`, and `columns` parameters.

# %%
with pd.ExcelWriter('NYC baby Data.xlsx') as excel_file:
    females.to_excel(excel_file, sheet_name='Females', index=False, columns=['Year of Birth', "Child's First Name", "Count"])
    males.to_excel(excel_file, sheet_name='Males', index=False, columns=['Year of Birth', "Child's First Name", "Count"])
