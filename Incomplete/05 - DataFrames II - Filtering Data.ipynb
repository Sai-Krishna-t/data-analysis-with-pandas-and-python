# %% [markdown]
# # DataFrames II: Filtering Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset + Memory Optimization

# %%
employees = pd.read_csv('employees.csv')
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %% [markdown]
# - The `info` method shows a summary of the `DataFrame` including missing values and data types.

# %%
employees.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    str
#  1   Gender             855 non-null    str
#  2   Start Date         1000 non-null   str
#  3   Last Login Time    1000 non-null   str
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    str
# dtypes: float64(1), int64(1), object(1), str(5)
# memory usage: 62.6+ KB

# %% [markdown]
# - The `pd.to_datetime`function method converts a `Series` to hold datetime values.
# - The `format` parameter informs pandas of the format that the times are stored in.
# - We pass symbols designating the segments of the string. For example, `%m` is for month and `%d` is for day.
# - Use the `astype` method to convert the values in a `Series` to another type.

# %%
employees['Start Date'].head()
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# 3     3/4/2005
# 4    1/24/1998
# Name: Start Date, dtype: str

# %%
pd.to_datetime(employees['Start Date'])
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[us]

# %%
pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[us]

# %% [markdown]
# - The `dt` attribute reveals an object with many datetime-related attributes and methods.
# - The `dt.time` attribute extracts only the time from each value in a datetime `Series`.

# %%
pd.to_datetime(employees['Last Login Time'])
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_9208\844589721.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(employees['Last Login Time'])
# 0     2026-05-26 12:42:00
# 1     2026-05-26 06:53:00
# 2     2026-05-26 11:17:00
# 3     2026-05-26 13:00:00
# 4     2026-05-26 16:47:00
#               ...
# 995   2026-05-26 06:09:00
# 996   2026-05-26 06:30:00
# 997   2026-05-26 12:39:00
# 998   2026-05-26 16:45:00
# 999   2026-05-26 18:24:00
# Name: Last Login Time, Length: 1000, dtype: datetime64[us]

# %%
employees['Last Login Time'].head()
# Out:
# 0    12:42 PM
# 1     6:53 AM
# 2    11:17 AM
# 3     1:00 PM
# 4     4:47 PM
# Name: Last Login Time, dtype: str

# %%
pd.to_datetime(employees['Last Login Time'], format="%H:%M %p")
# Out:
# 0     1900-01-01 12:42:00
# 1     1900-01-01 06:53:00
# 2     1900-01-01 11:17:00
# 3     1900-01-01 01:00:00
# 4     1900-01-01 04:47:00
#               ...
# 995   1900-01-01 06:09:00
# 996   1900-01-01 06:30:00
# 997   1900-01-01 12:39:00
# 998   1900-01-01 04:45:00
# 999   1900-01-01 06:24:00
# Name: Last Login Time, Length: 1000, dtype: datetime64[us]

# %%
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42:00   97308    6.945
# 1     Thomas    Male  3/31/1996        06:53:00   61933    4.170
# 2      Maria  Female  4/23/1993        11:17:00  130590   11.858
# 3      Jerry    Male   3/4/2005        01:00:00  138705    9.340
# 4      Larry    Male  1/24/1998        04:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %% [markdown]
# - Let's convert the `Senior Management` column into a Boolean column.
# - Let's convert the `Gender` column into a category column.

# %%
employees['Senior Management'] = employees['Senior Management'].astype(bool)
employees['Gender'] = employees['Gender'].astype('category')
employees['Team'] =  employees['Team'].astype('category')

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42:00   97308    6.945
# 1     Thomas    Male  3/31/1996        06:53:00   61933    4.170
# 2      Maria  Female  4/23/1993        11:17:00  130590   11.858
# 3      Jerry    Male   3/4/2005        01:00:00  138705    9.340
# 4      Larry    Male  1/24/1998        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    str
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   str
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), float64(1), int64(1), object(1), str(2)
# memory usage: 42.2+ KB

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head().info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         5 non-null      str
#  1   Gender             5 non-null      category
#  2   Start Date         5 non-null      datetime64[us]
#  3   Last Login Time    5 non-null      object
#  4   Salary             5 non-null      int64
#  5   Bonus %            5 non-null      float64
#  6   Senior Management  5 non-null      bool
#  7   Team               4 non-null      category
# dtypes: bool(1), category(2), datetime64[us](1), float64(1), int64(1), object(1), str(1)
# memory usage: 443.0+ bytes

# %% [markdown]
# ## Filter A DataFrame  Based On A Condition
# - Pandas needs a Boolean `Series` to perform a filter.
# - Pass the Boolean `Series` inside square brackets after the `DataFrame`.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
employees[employees['Gender'] != 'Male']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# ..         ...     ...        ...             ...     ...      ...
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 2                False               Finance
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# ..                 ...                   ...
# 989              False                 Legal
# 990               True       Client Services
# 991               True             Marketing
# 993               True           Engineering
# 995              False          Distribution
#
# [576 rows x 8 columns]

# %%
employees[employees['Team'] == 'Finance']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47:00  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
employees[employees['Team'] == 'Engineering']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 30   Christina  Female 2002-08-06        01:19:00  118780    9.096
# 50       Nancy  Female 2000-09-23        08:05:00   94976   13.830
# 54        Sara  Female 2007-08-15        09:23:00   83677    8.999
# 58     Theresa  Female 2010-04-11        07:18:00   72670    1.481
# ..         ...     ...        ...             ...     ...      ...
# 969      Linda  Female 2010-02-04        08:49:00   44486   17.308
# 980   Kimberly  Female 2013-01-26        12:57:00   46233    8.862
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 984      Maria  Female 2011-10-15        04:53:00   43455   13.040
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
#
#      Senior Management         Team
# 8                 True  Engineering
# 30                True  Engineering
# 50                True  Engineering
# 54               False  Engineering
# 58                True  Engineering
# ..                 ...          ...
# 969               True  Engineering
# 980               True  Engineering
# 983              False  Engineering
# 984              False  Engineering
# 993               True  Engineering
#
# [92 rows x 8 columns]

# %% [markdown]
# - Assign the Boolean `Series` to a variable for a simpler syntax.

# %%
male_gender = employees['Gender'] == 'Male'
employees[male_gender]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %% [markdown]
# - An existing Boolean column can serve as a filter.

# %%
employees[employees['Senior Management'] == True]
# but senior managemnt is already a boolean column so no need of True
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
employees[employees['Senior Management']]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %% [markdown]
# - We can generate a Boolean `Series` using a wide variety of operations (equality, inequality, less than, greater than, inclusion, etc)

# %%
print(employees['Salary'] > 110000)
print('\n', '*' * 50, '\n')
print(employees[employees['Salary'] > 110000])
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Salary, Length: 1000, dtype: bool
#
#  **************************************************
#
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
## bonus percentage
employees[employees['Bonus %'] < 1.5]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11        07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14        08:13:00  107391    1.260
# 175     Willie    Male 1998-02-17        08:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02        03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03        04:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12        08:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08        07:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19        01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12        01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27        06:40:00   93847    1.085
# 527      Helen     NaN 1993-12-02        01:42:00   45724    1.022
# 570      Kelly  Female 1996-08-16        03:09:00   41427    1.431
# 578     Amanda  Female 1982-03-17        11:46:00  107111    1.438
# 579     Harold    Male 2010-10-18        08:45:00   65673    1.187
# 617      Kathy  Female 2001-01-14        05:11:00   45682    1.451
# 618      Peter    Male 1992-11-24        05:43:00   69297    1.268
# 638    Frances  Female 1996-11-12        06:08:00  112467    1.433
# 652     Willie    Male 2009-12-05        05:39:00  141932    1.017
# 708      Steve    Male 2002-01-11        09:17:00   51821    1.197
# 732      Henry    Male 1986-05-12        02:04:00   59943    1.432
# 734        NaN  Female 1994-12-18        08:42:00  138807    1.400
# 746     Gloria  Female 2004-08-19        10:31:00   46602    1.027
# 912        Joe    Male 1998-12-08        10:28:00  126120    1.020
# 929    Theresa  Female 2001-04-27        09:17:00   75661    1.079
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
#
#      Senior Management                  Team
# 4                 True       Client Services
# 15               False               Product
# 58                True           Engineering
# 77                True             Marketing
# 175               True           Engineering
# 189              False                 Sales
# 217               True       Client Services
# 273               True               Product
# 279              False  Business Development
# 365              False       Human Resources
# 445              False                   NaN
# 481               True  Business Development
# 527              False               Product
# 570              False               Product
# 578               True               Product
# 579               True                 Legal
# 617               True             Marketing
# 618              False               Finance
# 638              False  Business Development
# 652               True           Engineering
# 708               True                 Legal
# 732              False               Finance
# 734               True       Human Resources
# 746               True  Business Development
# 912              False                   NaN
# 929               True                 Legal
# 954               True               Finance
# 997              False               Product

# %%
employees[employees['Start Date'] < '1985-01-01']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23        10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27        06:30:00  124008   13.464
# 37       Linda  Female 1981-10-19        08:49:00   57427    9.557
# ..         ...     ...        ...             ...     ...      ...
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %%
import datetime as dt
dt.time(12, 0)
# Out:
# datetime.time(12, 0)

# %%
## TIme - use datetime module
import datetime as dt
employees[employees['Last Login Time'] < dt.time(11, 0, 0)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 6                 True               Product
# ..                 ...                   ...
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 998              False  Business Development
# 999               True                 Sales
#
# [848 rows x 8 columns]

# %%
import pandas as pd
import datetime as dt

employees = pd.DataFrame({
    "Name": ["Sai", "John", "David"],
    "Last Login Time": [
        dt.time(9, 30),
        dt.time(12, 15),
        dt.time(10, 45)
    ]
})
employees
# Out:
#     Name Last Login Time
# 0    Sai        09:30:00
# 1   John        12:15:00
# 2  David        10:45:00

# %%
print(employees['Last Login Time'] < dt.time(11,0,0))
employees[employees['Last Login Time'] < dt.time(11,0,0)]
# Out:
# 0     True
# 1    False
# 2     True
# Name: Last Login Time, dtype: bool
#     Name Last Login Time
# 0    Sai        09:30:00
# 2  David        10:45:00

# %% [markdown]
# ## Filter with More than One Condition (AND)

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# - Add the `&` operator in between two Boolean `Series` to filter by multiple conditions.
# - Add parentheses around the individual `Series` to avoid errors/confusion.

# %%
(employees['Gender'] == 'Female') & (employees['Team'] == 'Marketing')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
employees[(employees['Gender'] == 'Female') & (employees['Team'] == 'Marketing')]
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 43      Marilyn  Female 1980-12-07        03:16:00   73524    5.207
# 62          NaN  Female 2007-06-12        05:25:00   58112   19.414
# 98         Tina  Female 2016-06-16        07:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28        01:23:00  113850    1.854
# 158       Norma  Female 1999-02-28        08:45:00  114412    8.756
# 201    Kimberly  Female 1997-07-15        05:57:00   36643    7.953
# 220         NaN  Female 1991-06-17        12:49:00   71945    5.560
# 305    Margaret  Female 1993-02-06        01:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25        03:01:00  145988   18.243
# 331      Evelyn  Female 1983-09-03        01:58:00   36759   17.269
# 379         NaN  Female 2002-09-18        12:39:00  118906    4.537
# 446      Cheryl  Female 1994-08-16        08:33:00   67150   15.850
# 468      Janice  Female 1997-06-28        01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23        01:22:00  117055    7.461
# 531    Virginia  Female 2010-05-02        09:10:00  123649   10.154
# 535      Louise  Female 1981-09-18        05:47:00   91462    8.205
# 568       Susan  Female 1986-04-18        09:31:00   90829   19.142
# 585     Shirley  Female 1988-04-16        11:09:00  132156    2.754
# 586        Rose  Female 2004-10-30        04:34:00   56961    7.585
# 617       Kathy  Female 2001-01-14        05:11:00   45682    1.451
# 625     Cynthia  Female 2015-06-29        06:38:00   82408    8.701
# 627        Anne  Female 1984-11-21        12:30:00  128305   16.636
# 629       Debra  Female 1983-03-12        12:19:00   74911   19.513
# 656        Lisa  Female 1982-02-09        06:44:00  113592   17.108
# 675       Diane  Female 2009-10-30        06:56:00  130577   12.791
# 676       Annie  Female 1992-06-06        10:04:00  138925    9.801
# 730      Nicole  Female 2009-04-26        12:40:00   66047   18.674
# 785         NaN  Female 1982-07-24        12:00:00   57811    8.941
# 811      Judith  Female 1989-09-03        11:16:00  134048    6.818
# 813      Evelyn  Female 2002-02-10        04:44:00  123621   19.767
# 817        Ruby  Female 2008-05-31        08:41:00   83112    4.083
# 824       Julia  Female 2014-08-18        03:12:00   97566    2.147
# 881        Ruby  Female 1980-01-28        11:08:00  142868    6.318
# 883     Kathryn  Female 1995-10-27        03:39:00   57300   18.015
# 894       Betty  Female 2002-11-19        10:40:00   37005    7.645
# 913        Lois  Female 2015-12-11        04:10:00   99747    6.168
# 930       Nancy  Female 2001-09-10        11:57:00   85213    2.386
# 942        Lori  Female 2015-11-20        01:15:00   75498    6.537
# 986       Donna  Female 1982-11-26        07:04:00   82871   17.999
# 991        Rose  Female 2002-08-25        05:12:00  134505   11.051
#
#      Senior Management       Team
# 43                True  Marketing
# 62                True  Marketing
# 98                True  Marketing
# 140              False  Marketing
# 158               True  Marketing
# 201              False  Marketing
# 220               True  Marketing
# 305              False  Marketing
# 319              False  Marketing
# 331               True  Marketing
# 379               True  Marketing
# 446               True  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 531               True  Marketing
# 535              False  Marketing
# 568              False  Marketing
# 585              False  Marketing
# 586              False  Marketing
# 617               True  Marketing
# 625               True  Marketing
# 627              False  Marketing
# 629              False  Marketing
# 656               True  Marketing
# 675              False  Marketing
# 676               True  Marketing
# 730               True  Marketing
# 785               True  Marketing
# 811               True  Marketing
# 813               True  Marketing
# 817              False  Marketing
# 824              False  Marketing
# 881              False  Marketing
# 883              False  Marketing
# 894               True  Marketing
# 913              False  Marketing
# 930               True  Marketing
# 942               True  Marketing
# 986              False  Marketing
# 991               True  Marketing

# %% [markdown]
# - We can assign the `Series` to variables to make the syntax more readable.
# - Variables also remove the need for parentheses.

# %%
female = employees['Gender'] == 'Female'
marketing = employees['Team'] == 'Marketing'
salary = employees['Salary'] > 100000
employees[female  & marketing & salary]
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 98         Tina  Female 2016-06-16        07:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28        01:23:00  113850    1.854
# 158       Norma  Female 1999-02-28        08:45:00  114412    8.756
# 305    Margaret  Female 1993-02-06        01:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25        03:01:00  145988   18.243
# 379         NaN  Female 2002-09-18        12:39:00  118906    4.537
# 468      Janice  Female 1997-06-28        01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23        01:22:00  117055    7.461
# 531    Virginia  Female 2010-05-02        09:10:00  123649   10.154
# 585     Shirley  Female 1988-04-16        11:09:00  132156    2.754
# 627        Anne  Female 1984-11-21        12:30:00  128305   16.636
# 656        Lisa  Female 1982-02-09        06:44:00  113592   17.108
# 675       Diane  Female 2009-10-30        06:56:00  130577   12.791
# 676       Annie  Female 1992-06-06        10:04:00  138925    9.801
# 811      Judith  Female 1989-09-03        11:16:00  134048    6.818
# 813      Evelyn  Female 2002-02-10        04:44:00  123621   19.767
# 881        Ruby  Female 1980-01-28        11:08:00  142868    6.318
# 991        Rose  Female 2002-08-25        05:12:00  134505   11.051
#
#      Senior Management       Team
# 98                True  Marketing
# 140              False  Marketing
# 158               True  Marketing
# 305              False  Marketing
# 319              False  Marketing
# 379               True  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 531               True  Marketing
# 585              False  Marketing
# 627              False  Marketing
# 656               True  Marketing
# 675              False  Marketing
# 676               True  Marketing
# 811               True  Marketing
# 813               True  Marketing
# 881              False  Marketing
# 991               True  Marketing

# %% [markdown]
# ## Filter with More than One Condition (OR)
# - Use the `|` operator in between two Boolean `Series` to filter by *either* condition.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# - Let's target employees who are either senior management OR who started before 1990-01-01.

# %%
senior_mngmt = employees['Senior Management']
started_in_80s = employees['Start Date'] < "1990-01-01"
employees[senior_mngmt | started_in_80s].head()
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18        01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %% [markdown]
# - Let's look for employees named Robert who work in Client Services OR have a start date after 2016-06-01.

# %%
robert = employees['First Name'] == 'Robert'
client = employees['Team'] == 'Client Services'
start_date = employees['Start Date'] > "2016-06-01"
employees[(robert & client) | start_date]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16        07:47:00  100705   16.961
# 387     Robert    Male 1994-10-29        04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15        12:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
employees[robert & (client | start_date)]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 387     Robert   Male 1994-10-29        04:26:00  123294   19.894
#
#      Senior Management             Team
# 387              False  Client Services

# %% [markdown]
# ## The isin Method
# - The `isin` method accepts a collection object like a list, tuple, or `Series`.
# - The method returns True for a row if its value is found within the collection.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# - Let's say we're targeting employees whose team is Legal, Sales, or Product.

# %%
legal_team = employees['Team'] == 'Legal'
sales_team = employees['Team'] == 'Sales'
product_team = employees['Team'] == 'Product'
# employees['Team'] is in ['Legal', 'Sales','Product']
employees[product_team | legal_team | sales_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
print(employees['Team'].isin(['Legal','Sales','Product']))
employees[employees['Team'].isin(['Legal','Sales','Product'])]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Team, Length: 1000, dtype: bool
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## The isnull and notnull Methods
# - The `isnull` method returns True for `NaN` values in a `Series`.
# - The `notnull` method returns True for present values in a `Series`.
# - The `isna` method is an alias for `isnull`.
# - The `notna` method is an alias for `notnull`.

# %%
employees['Gender'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'].isnull()]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22        07:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08        01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11        06:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20        02:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...    ...        ...             ...     ...      ...
# 961    Antonio    NaN 1989-06-18        09:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28        02:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10        04:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
employees['Gender'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %%
employees['Gender'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'].isna()]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22        07:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08        01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11        06:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20        02:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...    ...        ...             ...     ...      ...
# 961    Antonio    NaN 1989-06-18        09:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28        02:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10        04:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
employees['Gender'].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'].notna()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ## The between Method
# - The `between` method returns True if a `Series` value is found within its range.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees[(employees['Salary'] >= 60000) & (employees['Salary'] <= 80000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 29    Benjamin    Male 2005-01-26        10:06:00   79529    7.008
# ..         ...     ...        ...             ...     ...      ...
# 971    Patrick    Male 2002-12-30        02:01:00   75423    5.368
# 972     Victor     NaN 2006-07-28        02:49:00   76381   11.159
# 974      Harry    Male 2011-08-30        06:31:00   67656   16.455
# 978       Sean    Male 1983-01-17        02:23:00   66146   11.178
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 29                True                 Legal
# ..                 ...                   ...
# 971               True  Business Development
# 972               True                 Sales
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [169 rows x 8 columns]

# %%
employees[employees['Salary'].between(60000, 80000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 29    Benjamin    Male 2005-01-26        10:06:00   79529    7.008
# ..         ...     ...        ...             ...     ...      ...
# 971    Patrick    Male 2002-12-30        02:01:00   75423    5.368
# 972     Victor     NaN 2006-07-28        02:49:00   76381   11.159
# 974      Harry    Male 2011-08-30        06:31:00   67656   16.455
# 978       Sean    Male 1983-01-17        02:23:00   66146   11.178
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 29                True                 Legal
# ..                 ...                   ...
# 971               True  Business Development
# 972               True                 Sales
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [169 rows x 8 columns]

# %%
employees[employees['Bonus %'].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 40     Michael    Male 2008-10-10        11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24        12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23        02:01:00   48866    4.271
# ..         ...     ...        ...             ...     ...      ...
# 943      Wayne    Male 2006-09-08        11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18        09:37:00  103050    3.050
# 976     Denise  Female 1992-10-19        05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %%
print(employees[employees['Start Date'].between('1991-01-01', '1992-01-01')])
print('No of rows: ', len(employees[employees['Start Date'].between('1991-01-01', '1992-01-01')]))
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11        06:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02        01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27        01:59:00   64088    6.155
# 116        NaN    Male 1991-06-22        08:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14        02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09        06:52:00   42341    7.014
# 172       Sara  Female 1991-09-23        06:17:00   97058    9.402
# 220        NaN  Female 1991-06-17        12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11        07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29        06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01        02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19        02:54:00   76076    5.319
# 339    Michael    Male 1991-11-22        12:57:00   98753   16.443
# 537    Cynthia  Female 1991-09-14        01:08:00   51633   13.472
# 552    Barbara  Female 1991-09-02        03:41:00  127297   11.905
# 603       Carl     NaN 1991-10-26        08:11:00  100888   12.490
# 639     Amanda     NaN 1991-08-11        02:15:00   46665   19.391
# 704     Thomas    Male 1991-09-07        09:51:00   65251   11.211
# 725     Jeremy    Male 1991-05-19        01:40:00  131513    1.876
# 766     Justin    Male 1991-07-25        12:45:00  112975    9.699
# 771      Peter    Male 1991-05-22        01:39:00  102577   12.026
# 783        NaN     NaN 1991-04-15        03:39:00  132505   13.592
# 891    Timothy    Male 1991-08-25        10:37:00   92587    8.475
# 895     Janice     NaN 1991-11-19        06:02:00  139791   16.968
# 909     Donald    Male 1991-08-01        02:25:00   61999    6.466
# 923      Irene     NaN 1991-02-28        10:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               True                 Legal
# 148               True                 Sales
# 166               True                 Sales
# 172              False               Finance
# 220               True             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               True               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal
# No of rows:  27

# %%
emp_time = employees['Last Login Time'].between(dt.time(8, 30), dt.time(12, 30))
employees[emp_time]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 18       Diana  Female 1981-10-23        10:27:00  132940   19.082
# ..         ...     ...        ...             ...     ...      ...
# 977      Sarah  Female 1995-12-04        09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
#
#      Senior Management             Team
# 2                False          Finance
# 7                 True          Finance
# 10                True              NaN
# 13               False            Sales
# 18               False  Client Services
# ..                 ...              ...
# 977              False          Product
# 982               True  Human Resources
# 983              False      Engineering
# 988              False  Human Resources
# 992               True          Finance
#
# [316 rows x 8 columns]

# %% [markdown]
# ## The duplicated Method
# - The `duplicated` method returns True if a `Series` value is a duplicate.
# - Pandas will mark one occurrence of a repeated value as a non-duplicate.
# - Use the `keep` parameter to designate whether to consider the first or last occurrence of a repeated value as the non-duplicate.
# - Pass `False` to the `keep` parameter to mark all occurrences of repeated values as duplicates.
# - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
# - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
# - `False` : Mark all duplicates as ``True``.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees['First Name'] == 'Larry'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: First Name, Length: 1000, dtype: bool

# %%
employees[employees['First Name'].duplicated(keep='first')] # first occurance value shoud be a non duplicatevalue
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 23         NaN   Male 2012-06-14        04:19:00  125792    5.042
# 25         NaN   Male 2012-10-08        01:12:00   37076   18.576
# 32         NaN   Male 1998-08-21        02:27:00  122340    6.417
# 34       Jerry   Male 2004-01-10        12:56:00   95734   19.096
# 39         NaN   Male 2016-01-29        02:33:00  122173    7.797
# ..         ...    ...        ...             ...     ...      ...
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 23                True                   NaN
# 25                True       Client Services
# 32                True                   NaN
# 34               False       Client Services
# 39                True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [799 rows x 8 columns]

# %%
employees[employees['First Name'].duplicated(keep='last')] # last occurance value shoud be a non duplicatevalue
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 959     Albert    Male 1992-09-19        02:35:00   45094    5.850
# 960    Stephen    Male 1989-10-29        11:34:00   93997   18.093
# 970      Alice  Female 1988-09-03        08:54:00   63571   15.397
# 973    Russell    Male 2013-05-10        11:08:00  137359   11.105
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 959               True  Business Development
# 960               True  Business Development
# 970               True               Product
# 973              False  Business Development
# 982               True       Human Resources
#
# [799 rows x 8 columns]

# %%
employees[employees['First Name'].duplicated(keep=False)] # last occurance value shoud be a non duplicatevalue
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [991 rows x 8 columns]

# %% [markdown]
# - Use the tilde symbol (`~`) to invert a `Series's` values. True will become Falses, and Falses will become Trues.

# %%
employees[~employees['First Name'].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        03:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %%
employees[employees['First Name'] == 'Dennis']
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 5     Dennis   Male 1987-04-18        01:35:00  115163   10.125
#
#    Senior Management   Team
# 5              False  Legal

# %%
employees[employees['First Name'] == 'Angela']
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 8     Angela  Female 2005-11-22        06:29:00   95570   18.523
#
#    Senior Management         Team
# 8               True  Engineering

# %% [markdown]
# ## The drop_duplicates Method
# - The `drop_duplicates` method deletes rows with duplicate values.
# - By default, it will remove a row if *all* of its values are shared with another row.
# - The `subset` parameter configures the columns to look for duplicate values within.
# - `keep` : {'first', 'last', ``False``}, default 'first'
#
#     - Determines which duplicates (if any) to keep.
#
#         - 'first' : Drop duplicates except for the first occurrence.
#         - 'last' : Drop duplicates except for the last occurrence.
#         - ``False`` : Drop all duplicates.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.drop_duplicates()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %% [markdown]
# - Pass a list to `subset` parameter to look for duplicates across multiple columns.

# %%
employees.drop_duplicates(subset=['Senior Management', 'Team']).sort_values('Team')
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 33       Jean  Female 1993-12-18        09:07:00  119082   16.180
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 18      Diana  Female 1981-10-23        10:27:00  132940   19.082
# 60      Paula     NaN 2005-11-23        02:01:00   48866    4.271
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 54       Sara  Female 2007-08-15        09:23:00   83677    8.999
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 16     Jeremy    Male 2010-09-21        05:56:00   90370    7.369
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 11      Julie  Female 1997-10-26        03:19:00  102508   12.637
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 21    Matthew    Male 1995-09-05        02:12:00  100612   13.645
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 15    Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 45      Roger    Male 1980-04-17        11:32:00   88010   13.886
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 91      James     NaN 2005-01-26        11:00:00  128771    8.309
#
#     Senior Management                  Team
# 33              False  Business Development
# 9                True  Business Development
# 4                True       Client Services
# 18              False       Client Services
# 60              False          Distribution
# 40               True          Distribution
# 8                True           Engineering
# 54              False           Engineering
# 2               False               Finance
# 3                True               Finance
# 16              False       Human Resources
# 12               True       Human Resources
# 11               True                 Legal
# 5               False                 Legal
# 21              False             Marketing
# 0                True             Marketing
# 6                True               Product
# 15              False               Product
# 13              False                 Sales
# 45               True                 Sales
# 1                True                   NaN
# 91              False                   NaN

# %%
employees.drop_duplicates(subset='Gender')
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 20       Lois     NaN 1995-04-22        07:18:00   64714    4.934
#
#     Senior Management       Team
# 0                True  Marketing
# 2               False    Finance
# 20               True      Legal

# %%
employees.drop_duplicates(subset='Team')
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates(subset='Team', keep='first')
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates(subset='Team', keep='last')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 951        NaN  Female 2010-09-14        05:19:00  143638    9.662
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 951               True                   NaN
# 988              False       Human Resources
# 989              False                 Legal
# 990               True       Client Services
# 993               True           Engineering
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.drop_duplicates(subset='Team', keep=False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
employees.drop_duplicates(subset='First Name', keep=False)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        03:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %% [markdown]
# ## The where Method
# - Like the square brackets, the `where` method accepts a Boolean `Series` to filter the `DataFrame`.
# - The resulting `DataFrame` will be of the same length as the original.
# - Rows that do not satisfy the filtering criteria will have `NaN`s.
# - The `where` method is ideal when you want to preserve the original `DataFrame` structure.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
sal = employees['Salary'] > 100000
employees.where(sal)
# Out:
#     First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0          NaN     NaN        NaT             NaN       NaN      NaN
# 1          NaN     NaN        NaT             NaN       NaN      NaN
# 2        Maria  Female 1993-04-23        11:17:00  130590.0   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705.0    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004.0    1.389
# ..         ...     ...        ...             ...       ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483.0   16.655
# 996        NaN     NaN        NaT             NaN       NaN      NaN
# 997        NaN     NaN        NaT             NaN       NaN      NaN
# 998        NaN     NaN        NaT             NaN       NaN      NaN
# 999     Albert    Male 2012-05-15        06:24:00  129949.0   10.169
#
#     Senior Management             Team
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2               False          Finance
# 3                True          Finance
# 4                True  Client Services
# ..                ...              ...
# 995             False     Distribution
# 996               NaN              NaN
# 997               NaN              NaN
# 998               NaN              NaN
# 999              True            Sales
#
# [1000 rows x 8 columns]

# %%
employees['Salary'].where(sal)
# Out:
# 0           NaN
# 1           NaN
# 2      130590.0
# 3      138705.0
# 4      101004.0
#          ...
# 995    132483.0
# 996         NaN
# 997         NaN
# 998         NaN
# 999    129949.0
# Name: Salary, Length: 1000, dtype: float64

# %% [markdown]
# ## The query Method
# - The `query` method filters a `DataFrame` using a string argument.
# - Its argument is a more readable alternative to Boolean filtering.

# %%
employees = pd.read_csv('employees.csv').astype({
    "Senior Management": bool, "Gender": "category", "Team": "category"
})

employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format="%H:%M %p").dt.time

employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# - Use `and`, `or`, and `not` (or `&`, `|`, `~`) within the expression string.

# %%
employees.query('Salary > 100000')
employees.query('Salary < 100000')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# ..         ...     ...        ...             ...     ...      ...
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# ..                 ...                   ...
# 993               True           Engineering
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
#
# [591 rows x 8 columns]

# %%
employees.query("Gender == 'Female' and Team == 'Marketing'")
employees.query("Gender == 'Female' & Team == 'Marketing'")
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 43      Marilyn  Female 1980-12-07        03:16:00   73524    5.207
# 62          NaN  Female 2007-06-12        05:25:00   58112   19.414
# 98         Tina  Female 2016-06-16        07:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28        01:23:00  113850    1.854
# 158       Norma  Female 1999-02-28        08:45:00  114412    8.756
# 201    Kimberly  Female 1997-07-15        05:57:00   36643    7.953
# 220         NaN  Female 1991-06-17        12:49:00   71945    5.560
# 305    Margaret  Female 1993-02-06        01:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25        03:01:00  145988   18.243
# 331      Evelyn  Female 1983-09-03        01:58:00   36759   17.269
# 379         NaN  Female 2002-09-18        12:39:00  118906    4.537
# 446      Cheryl  Female 1994-08-16        08:33:00   67150   15.850
# 468      Janice  Female 1997-06-28        01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23        01:22:00  117055    7.461
# 531    Virginia  Female 2010-05-02        09:10:00  123649   10.154
# 535      Louise  Female 1981-09-18        05:47:00   91462    8.205
# 568       Susan  Female 1986-04-18        09:31:00   90829   19.142
# 585     Shirley  Female 1988-04-16        11:09:00  132156    2.754
# 586        Rose  Female 2004-10-30        04:34:00   56961    7.585
# 617       Kathy  Female 2001-01-14        05:11:00   45682    1.451
# 625     Cynthia  Female 2015-06-29        06:38:00   82408    8.701
# 627        Anne  Female 1984-11-21        12:30:00  128305   16.636
# 629       Debra  Female 1983-03-12        12:19:00   74911   19.513
# 656        Lisa  Female 1982-02-09        06:44:00  113592   17.108
# 675       Diane  Female 2009-10-30        06:56:00  130577   12.791
# 676       Annie  Female 1992-06-06        10:04:00  138925    9.801
# 730      Nicole  Female 2009-04-26        12:40:00   66047   18.674
# 785         NaN  Female 1982-07-24        12:00:00   57811    8.941
# 811      Judith  Female 1989-09-03        11:16:00  134048    6.818
# 813      Evelyn  Female 2002-02-10        04:44:00  123621   19.767
# 817        Ruby  Female 2008-05-31        08:41:00   83112    4.083
# 824       Julia  Female 2014-08-18        03:12:00   97566    2.147
# 881        Ruby  Female 1980-01-28        11:08:00  142868    6.318
# 883     Kathryn  Female 1995-10-27        03:39:00   57300   18.015
# 894       Betty  Female 2002-11-19        10:40:00   37005    7.645
# 913        Lois  Female 2015-12-11        04:10:00   99747    6.168
# 930       Nancy  Female 2001-09-10        11:57:00   85213    2.386
# 942        Lori  Female 2015-11-20        01:15:00   75498    6.537
# 986       Donna  Female 1982-11-26        07:04:00   82871   17.999
# 991        Rose  Female 2002-08-25        05:12:00  134505   11.051
#
#      Senior Management       Team
# 43                True  Marketing
# 62                True  Marketing
# 98                True  Marketing
# 140              False  Marketing
# 158               True  Marketing
# 201              False  Marketing
# 220               True  Marketing
# 305              False  Marketing
# 319              False  Marketing
# 331               True  Marketing
# 379               True  Marketing
# 446               True  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 531               True  Marketing
# 535              False  Marketing
# 568              False  Marketing
# 585              False  Marketing
# 586              False  Marketing
# 617               True  Marketing
# 625               True  Marketing
# 627              False  Marketing
# 629              False  Marketing
# 656               True  Marketing
# 675              False  Marketing
# 676               True  Marketing
# 730               True  Marketing
# 785               True  Marketing
# 811               True  Marketing
# 813               True  Marketing
# 817              False  Marketing
# 824              False  Marketing
# 881              False  Marketing
# 883              False  Marketing
# 894               True  Marketing
# 913              False  Marketing
# 930               True  Marketing
# 942               True  Marketing
# 986              False  Marketing
# 991               True  Marketing

# %%
employees.query("Gender == 'Female' or Team == 'Marketing'")
employees.query("Gender == 'Female' | Salary < 10000")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# ..                 ...                   ...
# 987               True               Finance
# 988              False       Human Resources
# 990               True       Client Services
# 991               True             Marketing
# 993               True           Engineering
#
# [431 rows x 8 columns]

# %% [markdown]
# - Use the `in` and `not in` operators to check inclusion/exclusion.

# %%
employees.query("Team in ['Finance', 'Marketing']")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management       Team
# 0                 True  Marketing
# 2                False    Finance
# 3                 True    Finance
# 7                 True    Finance
# 14                True    Finance
# ..                 ...        ...
# 987               True    Finance
# 991               True  Marketing
# 992               True    Finance
# 994               True  Marketing
# 996              False    Finance
#
# [200 rows x 8 columns]

# %%
employees.query("Team not in ['Legal', 'Finance', 'Marketing']")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# ..         ...     ...        ...             ...     ...      ...
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 4                 True       Client Services
# 6                 True               Product
# 8                 True           Engineering
# 9                 True  Business Development
# ..                 ...                   ...
# 993               True           Engineering
# 995              False          Distribution
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [712 rows x 8 columns]

# %% [markdown]
# - Use the `@` prefix to reference local variables.

# %%
min_salary = 130000

# %%
employees.query('Salary > min_salary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:232, in Scope.resolve(self, key, is_local)
#     231 if self.has_resolvers:
# --> 232     return self.resolvers[key]
#     234 # if we're here that means that we have no locals and we also have
#     235 # no resolvers
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\collections\__init__.py:1025, in ChainMap.__getitem__(self, key)
#    1024         pass
# -> 1025 return self.__missing__(key)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\collections\__init__.py:1017, in ChainMap.__missing__(self, key)
#    1016 def __missing__(self, key):
# -> 1017     raise KeyError(key)
#
# KeyError: 'min_salary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:243, in Scope.resolve(self, key, is_local)
#     239 try:
#     240     # last ditch effort we look in temporaries
#     241     # these are created when parsing indexing expressions
#     242     # e.g., df[df > 0]
# --> 243     return self.temps[key]
#     244 except KeyError as err:
#
# KeyError: 'min_salary'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 employees.query('Salary > min_salary')
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:5193, in DataFrame.query(self, expr, parser, engine, local_dict, global_dict, resolvers, level, inplace)
#    5189         if not isinstance(expr, str):
#    5190             msg = f"expr must be a string to be evaluated, {type(expr)} given"
#    5191             raise ValueError(msg)
#    5192
# -> 5193         res = self.eval(
#    5194             expr,
#    5195             level=level + 1,
#    5196             parser=parser,
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:5373, in DataFrame.eval(self, expr, inplace, **kwargs)
#    5369         if "target" not in kwargs:
#    5370             kwargs["target"] = self
#    5371         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    5372
# -> 5373         return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\eval.py:370, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     361 # get our (possibly passed-in) scope
#     362 env = ensure_scope(
#     363     level + 1,
#     364     global_dict=global_dict,
#    (...)    367     target=target,
#     368 )
# --> 370 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     372 if engine == "numexpr" and (
#     373     (
#     374         is_extension_array_dtype(parsed_expr.terms.return_type)
#    (...)    383     )
#     384 ):
#     385     warnings.warn(
#     386         "Engine has switched to 'python' because numexpr does not support "
#     387         "extension array dtypes. Please set your engine to python manually.",
#     388         RuntimeWarning,
#     389         stacklevel=find_stack_level(),
#     390     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:819, in Expr.__init__(self, expr, engine, parser, env, level)
#     817 self.parser = parser
#     818 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 819 self.terms = self.parse()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:838, in Expr.parse(self)
#     834 def parse(self):
#     835     """
#     836     Parse an expression.
#     837     """
# --> 838     return self._visitor.visit(self.expr)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:426, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     424     raise SyntaxError("only a single expression is allowed")
#     425 expr = node.body[0]
# --> 426 return self.visit(expr, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:429, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     428 def visit_Expr(self, node, **kwargs):
# --> 429     return self.visit(node.value, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:729, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     727     op = self.translate_In(ops[0])
#     728     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 729     return self.visit(binop)
#     731 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     732 left = node.left
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:541, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     540 def visit_BinOp(self, node, **kwargs):
# --> 541     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     542     left, right = self._maybe_downcast_constants(left, right)
#     543     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:462, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     460     left = self.visit(node.left, side="left")
#     461 if right is None:
# --> 462     right = self.visit(node.right, side="right")
#     463 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     464 return op, op_class, left, right
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:551, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     550 def visit_Name(self, node, **kwargs) -> Term:
# --> 551     return self.term_type(node.id, self.env, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and isinstance(res.ndim, int) and res.ndim > 2:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:245, in Scope.resolve(self, key, is_local)
#     243     return self.temps[key]
#     244 except KeyError as err:
# --> 245     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'min_salary' is not defined

# %%
employees.query('Salary > @min_salary')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 18       Diana  Female 1981-10-23        10:27:00  132940   19.082
# 36      Rachel  Female 2009-02-16        08:47:00  142032   12.599
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 9                 True  Business Development
# 18               False       Client Services
# 36               False  Business Development
# ..                 ...                   ...
# 981              False                 Legal
# 983              False           Engineering
# 987               True               Finance
# 991               True             Marketing
# 995              False          Distribution
#
# [156 rows x 8 columns]
