# %% [markdown]
# # Options and Settings

# %%
import pandas as pd

# %% [markdown]
# ## Changing Options with Attributes
# - The `pd.options` module configures Pandas's settings.
# - The `display` module deals with the presentation of data.

# %%
spotify = pd.read_csv('spotify.csv')
spotify
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# ..                      ...                  ...
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album    Genre  Duration (min)  Tempo (BPM)  \
# 0                      The Landscapes      R&B            3.74        105.4
# 1                        The Archives      R&B            3.82         76.9
# 2          Songs from the Underground      Pop            3.04        130.7
# 3                     The Territories     Rock            3.35        156.7
# 4                        The Chapters     Rock            2.77        153.5
# ..                                ...      ...             ...          ...
# 195                   Chapters Vol. 2     Rock            3.73        152.4
# 196  Songs from the Edge of the World  Hip-Hop            2.88         67.6
# 197                        The Echoes     Rock            4.87        104.3
# 198                   The Territories    Latin            2.60        118.6
# 199  Songs from the Edge of the World      Pop            4.64        103.4
#
#      Energy  Danceability  Loudness (dB)  Popularity  Streams (M)
# 0    0.5390        0.5747          -7.43          52        74.21
# 1    0.4047        0.8809          -6.85          49        15.44
# 2    0.6967        0.7497          -6.25          67       253.67
# 3    0.8623        0.5503          -8.31          72        10.00
# 4    0.7548        0.3262          -2.08          61        90.17
# ..      ...           ...            ...         ...          ...
# 195  0.9308        0.5013          -4.80          59        49.02
# 196  0.7090        0.7991          -5.96          35         0.10
# 197  0.7052        0.4378          -1.00          84       930.03
# 198  0.7875        0.6610          -5.40          72       211.98
# 199  0.7720        0.7726          -4.00          71       195.37
#
# [200 rows x 11 columns]

# %% [markdown]
# - The `max_rows` attribute sets the threshold/limit where the `DataFrame` rows will be truncated.
# - The `min_rows` attribute sets the minimum number of displayed rows when `max_rows` is exceeded.
# - Overwrite an attribute's value with an equal sign and the new value.

# %%
pd.options.display.max_rows
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.min_rows = 15

# %%
spotify
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# 5                   Horizon         Pacific Gold
# 6                   Silence          Omar Hassan
# ..                      ...                  ...
# 193          Hearts Tonight             Solstice
# 194           Silver Garden          Yuki Tanaka
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album    Genre  Duration (min)  Tempo (BPM)  \
# 0                      The Landscapes      R&B            3.74        105.4
# 1                        The Archives      R&B            3.82         76.9
# 2          Songs from the Underground      Pop            3.04        130.7
# 3                     The Territories     Rock            3.35        156.7
# 4                        The Chapters     Rock            2.77        153.5
# 5                        The Passages  Hip-Hop            3.37         83.5
# 6                        The Passages      Pop            1.84        120.2
# ..                                ...      ...             ...          ...
# 193                      The Horizons      Pop            2.34        109.8
# 194                        The Echoes      Pop            3.45        118.1
# 195                   Chapters Vol. 2     Rock            3.73        152.4
# 196  Songs from the Edge of the World  Hip-Hop            2.88         67.6
# 197                        The Echoes     Rock            4.87        104.3
# 198                   The Territories    Latin            2.60        118.6
# 199  Songs from the Edge of the World      Pop            4.64        103.4
#
#      Energy  Danceability  Loudness (dB)  Popularity  Streams (M)
# 0    0.5390        0.5747          -7.43          52        74.21
# 1    0.4047        0.8809          -6.85          49        15.44
# 2    0.6967        0.7497          -6.25          67       253.67
# 3    0.8623        0.5503          -8.31          72        10.00
# 4    0.7548        0.3262          -2.08          61        90.17
# 5    0.8791        0.9195          -4.72          66        57.09
# 6    0.6585        0.6766          -3.91          87       156.60
# ..      ...           ...            ...         ...          ...
# 193  0.7621        0.6972          -6.54          49         1.00
# 194  0.6259        0.5463          -3.93          63       238.78
# 195  0.9308        0.5013          -4.80          59        49.02
# 196  0.7090        0.7991          -5.96          35         0.10
# 197  0.7052        0.4378          -1.00          84       930.03
# 198  0.7875        0.6610          -5.40          72       211.98
# 199  0.7720        0.7726          -4.00          71       195.37
#
# [200 rows x 11 columns]

# %% [markdown]
# - The `max_columns` attribute sets the threshold/limit where the `DataFrame` columns will be truncated.

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_columns = 6

# %%
spotify # prints first 3 columns and last 3 columns
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# 5                   Horizon         Pacific Gold
# 6                   Silence          Omar Hassan
# ..                      ...                  ...
# 193          Hearts Tonight             Solstice
# 194           Silver Garden          Yuki Tanaka
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album  ... Loudness (dB)  Popularity  \
# 0                      The Landscapes  ...         -7.43          52
# 1                        The Archives  ...         -6.85          49
# 2          Songs from the Underground  ...         -6.25          67
# 3                     The Territories  ...         -8.31          72
# 4                        The Chapters  ...         -2.08          61
# 5                        The Passages  ...         -4.72          66
# 6                        The Passages  ...         -3.91          87
# ..                                ...  ...           ...         ...
# 193                      The Horizons  ...         -6.54          49
# 194                        The Echoes  ...         -3.93          63
# 195                   Chapters Vol. 2  ...         -4.80          59
# 196  Songs from the Edge of the World  ...         -5.96          35
# 197                        The Echoes  ...         -1.00          84
# 198                   The Territories  ...         -5.40          72
# 199  Songs from the Edge of the World  ...         -4.00          71
#
#      Streams (M)
# 0          74.21
# 1          15.44
# 2         253.67
# 3          10.00
# 4          90.17
# 5          57.09
# 6         156.60
# ..           ...
# 193         1.00
# 194       238.78
# 195        49.02
# 196         0.10
# 197       930.03
# 198       211.98
# 199       195.37
#
# [200 rows x 11 columns]

# %% [markdown]
# ## Changing Options with Functions
# - The `pd.get_option` function retrieves the current value for a pandas setting.
# - The `pd.set_option` function sets a new value for a pandas setting.
# - The `pd.describe_option` function provides documentation for a pandas setting.
# - The `pd.reset_option` function returns a pandas setting back to its default value.

# %%
spotify = pd.read_csv('spotify.csv')
spotify.head()
# Out:
#                     Track               Artist                       Album  \
# 0                   Roads   The Midnight Drift              The Landscapes
# 1  The Horizon of Nowhere  Starfall Collective                The Archives
# 2                Sky Away          Sam Kariuki  Songs from the Underground
# 3            Only Sunrise        Andre Laurent             The Territories
# 4                   Storm   The Broken Compass                The Chapters
#
#    ... Loudness (dB)  Popularity  Streams (M)
# 0  ...         -7.43          52        74.21
# 1  ...         -6.85          49        15.44
# 2  ...         -6.25          67       253.67
# 3  ...         -8.31          72        10.00
# 4  ...         -2.08          61        90.17
#
# [5 rows x 11 columns]

# %%
pd.options.display.min_rows
# Out:
# 15

# %%
pd.get_option('display.min_rows')
pd.get_option('display.max_rows')
pd.get_option('display.max_columns')
# Out:
# 6

# %%
pd.set_option('display.min_rows', 14)
pd.set_option('display.max_columns', 6)
spotify
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# 5                   Horizon         Pacific Gold
# 6                   Silence          Omar Hassan
# ..                      ...                  ...
# 193          Hearts Tonight             Solstice
# 194           Silver Garden          Yuki Tanaka
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album  ... Loudness (dB)  Popularity  \
# 0                      The Landscapes  ...         -7.43          52
# 1                        The Archives  ...         -6.85          49
# 2          Songs from the Underground  ...         -6.25          67
# 3                     The Territories  ...         -8.31          72
# 4                        The Chapters  ...         -2.08          61
# 5                        The Passages  ...         -4.72          66
# 6                        The Passages  ...         -3.91          87
# ..                                ...  ...           ...         ...
# 193                      The Horizons  ...         -6.54          49
# 194                        The Echoes  ...         -3.93          63
# 195                   Chapters Vol. 2  ...         -4.80          59
# 196  Songs from the Edge of the World  ...         -5.96          35
# 197                        The Echoes  ...         -1.00          84
# 198                   The Territories  ...         -5.40          72
# 199  Songs from the Edge of the World  ...         -4.00          71
#
#      Streams (M)
# 0          74.21
# 1          15.44
# 2         253.67
# 3          10.00
# 4          90.17
# 5          57.09
# 6         156.60
# ..           ...
# 193         1.00
# 194       238.78
# 195        49.02
# 196         0.10
# 197       930.03
# 198       211.98
# 199       195.37
#
# [200 rows x 11 columns]

# %%
pd.set_option('display.max_rows', None) # get all rows
spotify
# Out:
#                           Track                          Artist  \
# 0                         Roads              The Midnight Drift
# 1        The Horizon of Nowhere             Starfall Collective
# 2                      Sky Away                     Sam Kariuki
# 3                  Only Sunrise                   Andre Laurent
# 4                         Storm              The Broken Compass
# 5                       Horizon                    Pacific Gold
# 6                       Silence                     Omar Hassan
# 7             Through the Stars             The Northern Lights
# 8               Above the River                      Elena Ruiz
# 9              Dancing Mountain              The Broken Compass
# 10       Breathing in the Light                    Chloe Dubois
# 11       Waiting in the Horizon                   Blue Meridian
# 12                        Waves                     Sam Kariuki
# 13                       Dreams                    Priya Sharma
# 14                 Every Chance                     Omar Hassan
# 15         Waiting in the Stars               Phantom Frequency
# 16               Golden Horizon             Starfall Collective
# 17                  City Inside              The Broken Compass
# 18               Another Chance                     Yuki Tanaka
# 19             Above the Garden                     Neon Parish
# 20                 Fading River                     Sam Kariuki
# 21                Another Night                   Infinite Loop
# 22                Waves Tonight                   Emerald Coast
# 23               Above the City           The Silent Architects
# 24                Endless Storm                      Sofia Vega
# 25          Running in the City                     Derek Huang
# 26                  Lost Dreams                  Gabriel Santos
# 27         Falling in the Storm                    Priya Sharma
# 28          Through the Silence                    Sienna Blake
# 29                    City Away           The Silent Architects
# 30         The Waves of Nowhere             Starfall Collective
# 31              Every Heartbeat                 Destiny Morales
# 32          Running in the Rain                    Liam O'Brien
# 33                        Light                    Echo Chamber
# 34                     Mountain              The Broken Compass
# 35      Falling in the Mountain                  Nova Syndicate
# 36             Beyond the Waves                    Liam O'Brien
# 37              Under the Light                     Omar Hassan
# 38                 City Forever                    Liam O'Brien
# 39                Electric City                       Maya Chen
# 40        Dreaming in the Roads                     Sam Kariuki
# 41                 First Chance              The Midnight Drift
# 42                          Sky           The Silent Architects
# 43           The Sky of Forever                   Andre Laurent
# 44                   Neon Storm                   Blue Meridian
# 45                   Stars Away                    Pacific Gold
# 46                Roads Tonight              The Wandering Suns
# 47                        Ocean        The Paper Kites Ensemble
# 48                Storm Forever                    Aurora Skies
# 49      Breathing in the Signal             The Northern Lights
# 50                         Rain                    Tomas Rivera
# 51              Into the Garden               Phantom Frequency
# 52      The Mountain of Nowhere              Midnight Orchestra
# 53                       Hearts                   Zara Mitchell
# 54                   River Away                   Emerald Coast
# 55                  Golden Fire                    Echo Chamber
# 56             Under the Hearts                    Chloe Dubois
# 57                  Last Chance                    Pacific Gold
# 58       Running in the Silence                       Ryan Choi
# 59             Under the Dreams                 Isaiah Thompson
# 60                Fading Signal                 Destiny Morales
# 61                       Echoes                   Blue Meridian
# 62         Waiting in the Roads                      Sofia Vega
# 63                 Another Song                    Chloe Dubois
# 64                       Memory                     Yuki Tanaka
# 65        The City of Yesterday                     Nina Volkov
# 66                 Ocean Inside                      Elena Ruiz
# 67               Golden Silence                     Derek Huang
# 68                   First Song                      Elena Ruiz
# 69               Only Heartbeat                       Ryan Choi
# 70                   Lost Roads                    Tomas Rivera
# 71      The Waves of Everything                       Ryan Choi
# 72        The Hearts of Forever                    Kai Nakamura
# 73       Falling in the Silence                     Yuki Tanaka
# 74                   Lost Light                        Solstice
# 75                 Signal Again             Starfall Collective
# 76              Crystal Horizon               The Glass Animals
# 77                  Every Dance                   Blue Meridian
# 78               Dreams Forever        The Paper Kites Ensemble
# 79     The Hearts of Everything                     Omar Hassan
# 80       The Horizon of Forever                    Echo Chamber
# 81               Electric Ocean      The Crystal Method Tribute
# 82                Shadow Memory      The Crystal Method Tribute
# 83           Above the Mountain                     Aisha Patel
# 84              Under the Stars              The Wandering Suns
# 85        Waiting in the Hearts                     Neon Parish
# 86               Signal Tonight                 James Whitfield
# 87                   Only Night                    Aurora Skies
# 88               Spinning Waves                    Echo Chamber
# 89                River Forever                  Velvet Horizon
# 90     The Memory of Everything                   Blue Meridian
# 91   The Mountain of Everything                   Emerald Coast
# 92                         City                   Emerald Coast
# 93             Above the Hearts             The Northern Lights
# 94                  Storm Again                  Horizon Theory
# 95                Another Dance                     Sam Kariuki
# 96                 Golden Storm                 Destiny Morales
# 97               Signal Forever                     Omar Hassan
# 98           Under the Mountain                   Emerald Coast
# 99            Through the Roads                   Dusk Protocol
# 100             Endless Horizon                   Emerald Coast
# 101                  Fire Again                        Solstice
# 102              Last Heartbeat           The Silent Architects
# 103                       Stars                   Dusk Protocol
# 104              Garden Forever                    Amara Okafor
# 105        Breathing in the Sky                        Solstice
# 106                 Neon Dreams                       Ryan Choi
# 107                 Ocean Again                    Kai Nakamura
# 108               Endless Stars                    Aurora Skies
# 109       The Echoes of Nowhere                   Emerald Coast
# 110    Breathing in the Horizon                 Isaiah Thompson
# 111                 Only Chance                  Horizon Theory
# 112               Rising Dreams                      Sofia Vega
# 113              Dreams Tonight                    Tomas Rivera
# 114      Breathing in the Roads                        Solstice
# 115        The River of Forever                    Aurora Skies
# 116              Mountain Again                       Maya Chen
# 117           Through the Storm                   Dusk Protocol
# 118               Every Sunrise                   Blue Meridian
# 119            Into the Silence                   Emerald Coast
# 120                 First Night                        Solstice
# 121            Under the Garden                   Infinite Loop
# 122                  Last Night                    Crimson Tide
# 123                Rain Tonight             Starfall Collective
# 124               Fading Hearts                     Omar Hassan
# 125       The Memory of Forever                     Yuki Tanaka
# 126            Beyond the Storm                     Aisha Patel
# 127       Falling in the Garden                     Derek Huang
# 128       The Garden of Forever                  Nova Syndicate
# 129          Through the Dreams                     Sam Kariuki
# 130                      Signal              Midnight Orchestra
# 131    Dreaming in the Mountain                      Sofia Vega
# 132            Above the Echoes                   Infinite Loop
# 133     Breathing in the Garden        The Paper Kites Ensemble
# 134                  Velvet Sky                  Nova Syndicate
# 135   The Mountain of Yesterday                   Emerald Coast
# 136     The Roads of Everything                     Nina Volkov
# 137             Under the Storm                     Omar Hassan
# 138             Horizon Tonight                    Chloe Dubois
# 139                Thunder Fire                   Marcus Reeves
# 140     The Horizon of Tomorrow                     Omar Hassan
# 141              Endless Garden                    Kai Nakamura
# 142      Waiting in the Silence                    Amara Okafor
# 143              Hearts Forever               Phantom Frequency
# 144                      Garden             The Northern Lights
# 145      The Ocean of Yesterday                  Gabriel Santos
# 146     Breathing in the Hearts                   Dusk Protocol
# 147              Into the Waves      The Crystal Method Tribute
# 148        Falling in the Light                   Dusk Protocol
# 149                Endless City                     Yuki Tanaka
# 150            Into the Horizon                      Elena Ruiz
# 151            Above the Memory              The Broken Compass
# 152      The Hearts of Tomorrow              Midnight Orchestra
# 153                Stars Inside                 Isaiah Thompson
# 154              Thunder Garden                    Pacific Gold
# 155          Beyond the Horizon                   Infinite Loop
# 156      The Roads of Yesterday             Starfall Collective
# 157       Falling in the Echoes                    Amara Okafor
# 158       Falling in the Memory               Phantom Frequency
# 159             Silence Forever              The Wandering Suns
# 160        Running in the Ocean  The Velvet Underground Revival
# 161                Last Sunrise                    Crimson Tide
# 162              Fading Horizon                 Isaiah Thompson
# 163    The Signal of Everything                   Marcus Reeves
# 164       Waiting in the Dreams                   Dusk Protocol
# 165       The Garden of Nowhere                   Marcus Reeves
# 166             First Heartbeat              The Wandering Suns
# 167                  Neon Stars                  Gabriel Santos
# 168     The Storm of Everything                   Blue Meridian
# 169               Endless River                   Andre Laurent
# 170                 Wild Signal             Starfall Collective
# 171        The Roads of Forever                     Derek Huang
# 172            Above the Signal                   Andre Laurent
# 173                 First Dance        The Paper Kites Ensemble
# 174          Through the Memory                     Omar Hassan
# 175                  Neon Ocean                  Gabriel Santos
# 176     Dreaming in the Horizon             The Northern Lights
# 177         Falling in the City        The Paper Kites Ensemble
# 178       The Storm of Tomorrow                  Horizon Theory
# 179              Into the River                       Ryan Choi
# 180                  Every Song           The Silent Architects
# 181        The Waves of Forever                   Emerald Coast
# 182                Hidden Storm                   Andre Laurent
# 183               First Sunrise                        Solstice
# 184      The Silence of Nowhere                      Sofia Vega
# 185           Beyond the Hearts                 Destiny Morales
# 186             Dancing Horizon             Starfall Collective
# 187       Breathing in the City                   Zara Mitchell
# 188              Garden Tonight                     Aisha Patel
# 189       Dreaming in the Ocean                  Nova Syndicate
# 190          Through the Garden           The Silent Architects
# 191              Echoes Tonight                    Pacific Gold
# 192                Broken River              The Midnight Drift
# 193              Hearts Tonight                        Solstice
# 194               Silver Garden                     Yuki Tanaka
# 195          Waiting in the Sky                     Nina Volkov
# 196                 Waves Again                     Luna Torres
# 197       The Roads of Tomorrow                      Sofia Vega
# 198             Another Sunrise              The Wandering Suns
# 199               Silence Again                     Luna Torres
#
#                                 Album  ... Loudness (dB)  Popularity  \
# 0                      The Landscapes  ...         -7.43          52
# 1                        The Archives  ...         -6.85          49
# 2          Songs from the Underground  ...         -6.25          67
# 3                     The Territories  ...         -8.31          72
# 4                        The Chapters  ...         -2.08          61
# 5                        The Passages  ...         -4.72          66
# 6                        The Passages  ...         -3.91          87
# 7                          The Echoes  ...         -6.88          74
# 8                   Notes on Solitude  ...         -8.53          51
# 9                          The Echoes  ...         -3.28          51
# 10            Notes on the Other Side  ...         -5.18          55
# 11                    The Reflections  ...         -3.92          28
# 12                  Dimensions Vol. 3  ...         -7.64          56
# 13                    The Frequencies  ...         -5.02          58
# 14   Songs from the Late Night Studio  ...         -7.87          70
# 15                     The Landscapes  ...         -3.97          70
# 16                Midnight Departures  ...         -4.37          15
# 17             Songs from the Rooftop  ...         -3.12          64
# 18                Quantum Frequencies  ...         -8.44          89
# 19                  Notes on Paradise  ...         -4.00          57
# 20             Welcome to the Unknown  ...         -2.98          55
# 21               Notes on the Unknown  ...         -5.37          46
# 22                A Guide to Paradise  ...         -7.03          56
# 23             Welcome to the Unknown  ...         -5.07          62
# 24                   Lucid Landscapes  ...         -2.64          30
# 25               Electric Territories  ...         -2.82          48
# 26             Songs from the Rooftop  ...         -4.76          55
# 27                A Guide to Solitude  ...         -4.81           4
# 28   Songs from the Edge of the World  ...         -3.96          70
# 29                   Movements Vol. 2  ...         -8.40          47
# 30             Songs from the Rooftop  ...         -5.37          68
# 31                       The Passages  ...         -7.34          72
# 32                Infinite Landscapes  ...         -5.02          39
# 33                 Crimson Landscapes  ...         -6.07          60
# 34            Notes on the Other Side  ...        -10.07          48
# 35             Songs from the Rooftop  ...         -2.84          40
# 36                 Crimson Dimensions  ...         -7.48          84
# 37                   Portraits Vol. 2  ...         -5.98          16
# 38                   Crimson Chapters  ...         -1.81          40
# 39                 The Constellations  ...         -6.05          40
# 40                  Ethereal Horizons  ...         -1.00          68
# 41                       The Archives  ...         -1.72          51
# 42                      The Portraits  ...         -5.06          50
# 43                Welcome to Solitude  ...         -6.16          38
# 44             Songs from the Rooftop  ...         -4.83          34
# 45                  Departures Vol. 2  ...         -5.94          84
# 46                  Departures Vol. 3  ...         -3.44          79
# 47         Songs from the Underground  ...         -8.60          37
# 48                   Portraits Vol. 2  ...         -3.08          51
# 49                 Frequencies Vol. 1  ...         -1.77          53
# 50         Songs from the Underground  ...         -5.30          70
# 51               Electric Reflections  ...         -5.92          27
# 52   Songs from the Late Night Studio  ...         -2.28          71
# 53                     The Landscapes  ...         -6.96          42
# 54                     The Departures  ...         -5.26          73
# 55                   Movements Vol. 3  ...         -3.37          43
# 56          Welcome to the Other Side  ...         -5.36          18
# 57   Songs from the Edge of the World  ...         -3.19          36
# 58   Songs from the Late Night Studio  ...         -6.75          69
# 59                         The Echoes  ...         -8.40          66
# 60                    The Territories  ...         -2.48          38
# 61            Notes on the Other Side  ...         -4.60          14
# 62   Songs from the Basement Sessions  ...         -6.80          82
# 63   Songs from the Basement Sessions  ...         -4.03          76
# 64             Songs from the Rooftop  ...         -1.91          23
# 65                Ethereal Boundaries  ...         -8.71          81
# 66               Restless Frequencies  ...         -2.00          81
# 67                 Shattered Chapters  ...         -5.88          67
# 68        Letters from the In-Between  ...         -4.41          28
# 69   Songs from the Basement Sessions  ...         -6.02          73
# 70            Restless Constellations  ...         -7.25          50
# 71                    Passages Vol. 3  ...         -6.32          51
# 72                 Territories Vol. 2  ...         -9.76          37
# 73               Ethereal Frequencies  ...         -8.35          91
# 74                      Echoes Vol. 1  ...         -4.93           6
# 75              Sacred Constellations  ...         -6.10          69
# 76                     The Dimensions  ...        -18.32          39
# 77                  Twilight Chapters  ...         -4.08          82
# 78                  Landscapes Vol. 1  ...        -12.26           3
# 79                      The Movements  ...        -12.51          26
# 80                    The Frequencies  ...         -5.40          70
# 81   Songs from the Basement Sessions  ...         -5.09          80
# 82         Songs from the Underground  ...         -5.93          50
# 83                    Archives Vol. 3  ...         -9.74          42
# 84   Songs from the Basement Sessions  ...         -5.44          62
# 85         Songs from the Underground  ...         -5.49          82
# 86                 Frequencies Vol. 3  ...         -8.50          73
# 87                      The Portraits  ...         -5.36          80
# 88   Songs from the Late Night Studio  ...         -3.49          51
# 89   Songs from the Edge of the World  ...         -5.74          36
# 90                Infinite Landscapes  ...         -7.12          56
# 91                 Frequencies Vol. 2  ...         -3.60          65
# 92                 Frequencies Vol. 2  ...         -3.79          24
# 93   Songs from the Basement Sessions  ...         -4.59          35
# 94                    The Frequencies  ...         -6.02          55
# 95                 Reflections Vol. 2  ...         -3.86          70
# 96                 Frequencies Vol. 3  ...         -5.85          55
# 97           Letters from the Unknown  ...        -10.85          82
# 98              Letters from Paradise  ...         -7.66          46
# 99              Letters from Paradise  ...         -6.15          50
# 100  Songs from the Basement Sessions  ...         -6.22          44
# 101                 Boundaries Vol. 2  ...         -2.96          55
# 102                 Departures Vol. 3  ...         -5.52          27
# 103  Songs from the Edge of the World  ...         -5.22          48
# 104  Songs from the Basement Sessions  ...         -5.15          83
# 105                Frequencies Vol. 1  ...         -4.29          72
# 106  Songs from the Edge of the World  ...         -6.38          67
# 107  Songs from the Late Night Studio  ...         -5.38          90
# 108                Frequencies Vol. 1  ...         -5.78          36
# 109                 Restless Chapters  ...         -6.73          66
# 110            Crimson Constellations  ...         -2.49          63
# 111                      Lucid Echoes  ...         -9.66          75
# 112                 Landscapes Vol. 1  ...         -7.71          84
# 113                Frequencies Vol. 2  ...         -5.15          48
# 114               Twilight Dimensions  ...         -7.35          61
# 115        Songs from the Underground  ...         -8.41          34
# 116           Electric Constellations  ...         -5.24          48
# 117        Songs from the Underground  ...         -5.27          55
# 118              Shattered Boundaries  ...         -3.49          39
# 119                Territories Vol. 1  ...         -4.89          52
# 120                    The Boundaries  ...         -7.34          88
# 121                 Electric Chapters  ...         -6.75          87
# 122             Letters from Paradise  ...         -3.04          41
# 123               Welcome to Solitude  ...         -7.59          27
# 124                 Sacred Boundaries  ...         -5.13          33
# 125        Songs from the Underground  ...         -8.59          24
# 126               Welcome to Paradise  ...         -2.06          68
# 127                 Landscapes Vol. 1  ...         -9.98          72
# 128                Infinite Portraits  ...         -9.77          52
# 129        Songs from the Underground  ...         -5.19          19
# 130              Electric Frequencies  ...         -3.97          38
# 131            Songs from the Rooftop  ...         -3.68          93
# 132        Songs from the Underground  ...         -4.30          22
# 133                   The Territories  ...         -6.48          62
# 134                      The Horizons  ...         -8.56          44
# 135           Notes on the Other Side  ...         -2.07          40
# 136                 Landscapes Vol. 2  ...         -6.91          52
# 137                     The Portraits  ...         -2.38          33
# 138                   The Frequencies  ...         -7.60          60
# 139  Songs from the Late Night Studio  ...         -5.30          26
# 140                    The Dimensions  ...         -6.90          77
# 141               Welcome to Paradise  ...         -8.78          72
# 142                   The Territories  ...         -5.34          37
# 143              Electric Reflections  ...         -5.44          41
# 144                Shattered Passages  ...         -2.77          73
# 145  Songs from the Edge of the World  ...         -6.31          60
# 146               A Guide to Solitude  ...         -6.70          43
# 147            A Guide to the Unknown  ...         -3.73          30
# 148  Songs from the Basement Sessions  ...         -6.41          65
# 149                    The Boundaries  ...         -9.33          38
# 150                      The Passages  ...         -2.13          95
# 151                    The Landscapes  ...         -5.28          30
# 152         Welcome to the Other Side  ...         -8.19          62
# 153                  Movements Vol. 3  ...         -2.44          86
# 154                      The Passages  ...         -7.22          46
# 155            Songs from the Rooftop  ...         -9.49          79
# 156                   Passages Vol. 1  ...         -9.28          43
# 157                 Golden Departures  ...         -8.01          78
# 158  Songs from the Edge of the World  ...         -7.64          56
# 159           Restless Constellations  ...         -1.00          33
# 160                 Notes on Paradise  ...         -7.86          72
# 161           Midnight Constellations  ...         -3.99          63
# 162            A Guide to the Unknown  ...         -7.82          64
# 163             Constellations Vol. 2  ...         -4.40          14
# 164                Crimson Dimensions  ...         -2.98          82
# 165                   Horizons Vol. 1  ...        -10.98          45
# 166        Songs from the Underground  ...         -6.33          44
# 167                   Lucid Movements  ...         -4.94          59
# 168  Songs from the Late Night Studio  ...        -14.63          37
# 169                 Boundaries Vol. 2  ...         -3.20          41
# 170             Constellations Vol. 2  ...         -9.88          44
# 171                   Archives Vol. 1  ...         -5.91          67
# 172                      The Archives  ...         -5.97          27
# 173                  Movements Vol. 3  ...         -7.37          37
# 174                Frequencies Vol. 3  ...         -2.82          64
# 175                      The Passages  ...         -5.20          30
# 176                 Lucid Territories  ...         -6.65          28
# 177              Infinite Frequencies  ...         -5.73          47
# 178        Songs from the Underground  ...         -4.17          33
# 179  Songs from the Basement Sessions  ...         -6.41          55
# 180                    The Boundaries  ...         -4.46          49
# 181              Restless Frequencies  ...         -3.26          70
# 182  Songs from the Edge of the World  ...         -8.52          45
# 183  Songs from the Late Night Studio  ...         -7.52          87
# 184               Welcome to Paradise  ...         -8.70          50
# 185         Welcome to the In-Between  ...         -5.21          21
# 186                     Echoes Vol. 1  ...         -5.19          23
# 187                     The Movements  ...         -4.99          56
# 188         Welcome to the In-Between  ...         -5.30          53
# 189                     The Movements  ...         -4.58          58
# 190              Twilight Frequencies  ...         -3.72          68
# 191             Letters from Solitude  ...         -7.07          89
# 192        Songs from the Underground  ...         -4.56          44
# 193                      The Horizons  ...         -6.54          49
# 194                        The Echoes  ...         -3.93          63
# 195                   Chapters Vol. 2  ...         -4.80          59
# 196  Songs from the Edge of the World  ...         -5.96          35
# 197                        The Echoes  ...         -1.00          84
# 198                   The Territories  ...         -5.40          72
# 199  Songs from the Edge of the World  ...         -4.00          71
#
#      Streams (M)
# 0          74.21
# 1          15.44
# 2         253.67
# 3          10.00
# 4          90.17
# 5          57.09
# 6         156.60
# 7         391.30
# 8          37.69
# 9          35.43
# 10        119.83
# 11          0.10
# 12         25.41
# 13         25.75
# 14         10.00
# 15        157.87
# 16         10.27
# 17        248.63
# 18        323.52
# 19         20.22
# 20         40.63
# 21         39.53
# 22         57.54
# 23         29.09
# 24          9.94
# 25         19.92
# 26         28.40
# 27          0.10
# 28         10.00
# 29         19.19
# 30         10.00
# 31         10.00
# 32          8.44
# 33        127.69
# 34         48.19
# 35         19.03
# 36        874.93
# 37          6.89
# 38          0.10
# 39         21.99
# 40        236.46
# 41         25.89
# 42         46.53
# 43          9.73
# 44          1.49
# 45        939.98
# 46         10.00
# 47          5.56
# 48         73.53
# 49         58.72
# 50        359.38
# 51          7.04
# 52        406.56
# 53         31.55
# 54        213.43
# 55         88.27
# 56          8.60
# 57          3.03
# 58         23.35
# 59        381.35
# 60          6.12
# 61         22.07
# 62       1263.93
# 63         78.70
# 64          0.90
# 65        172.18
# 66        840.63
# 67        111.68
# 68          7.94
# 69        291.30
# 70         33.85
# 71         41.86
# 72         12.99
# 73        668.52
# 74         14.54
# 75        211.61
# 76         14.68
# 77        754.24
# 78         16.85
# 79          9.65
# 80        222.55
# 81        270.59
# 82         41.13
# 83          1.00
# 84        418.92
# 85        661.71
# 86        290.98
# 87         58.54
# 88         67.29
# 89         12.78
# 90         49.53
# 91         50.32
# 92         23.13
# 93          2.69
# 94         56.68
# 95        261.69
# 96         72.10
# 97       1091.40
# 98         41.12
# 99          1.04
# 100        24.49
# 101         3.74
# 102        14.34
# 103       117.72
# 104       891.43
# 105       164.88
# 106       170.18
# 107      1566.45
# 108         0.10
# 109       191.09
# 110        63.24
# 111       179.42
# 112       692.26
# 113        71.80
# 114       131.86
# 115         0.10
# 116        11.63
# 117        69.63
# 118        21.24
# 119         1.00
# 120       278.35
# 121       316.85
# 122        67.23
# 123         0.10
# 124         5.39
# 125        13.76
# 126       302.62
# 127       252.46
# 128         1.00
# 129         9.64
# 130         0.60
# 131      1842.18
# 132         9.29
# 133        55.03
# 134         1.00
# 135        16.26
# 136       108.63
# 137         0.10
# 138        89.08
# 139         0.10
# 140       553.77
# 141        89.78
# 142        10.23
# 143        60.36
# 144       477.84
# 145         1.00
# 146        29.54
# 147        15.22
# 148       550.07
# 149        21.96
# 150      1141.44
# 151         7.96
# 152       261.16
# 153       756.42
# 154         1.00
# 155       101.56
# 156        24.92
# 157        81.53
# 158        38.32
# 159         6.03
# 160       150.68
# 161       433.49
# 162        10.00
# 163         0.33
# 164       579.90
# 165       120.42
# 166         1.08
# 167        55.92
# 168        15.66
# 169        48.54
# 170        52.21
# 171       253.08
# 172         6.54
# 173        21.91
# 174       296.36
# 175        16.10
# 176         2.92
# 177        30.21
# 178         2.27
# 179        66.05
# 180        67.41
# 181       346.75
# 182        38.58
# 183       799.68
# 184        10.85
# 185        13.49
# 186        10.25
# 187        76.19
# 188        70.20
# 189         1.00
# 190       231.91
# 191       959.74
# 192       107.65
# 193         1.00
# 194       238.78
# 195        49.02
# 196         0.10
# 197       930.03
# 198       211.98
# 199       195.37
#
# [200 rows x 11 columns]

# %%
pd.describe_option('display.max_rows')
# Out:
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view.
#
#     'None' value means unlimited. Beware that printing a large number of rows
#     could cause your rendering environment (the browser, etc.) to crash.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: None]

# %%
pd.reset_option("display.max_rows")

# %%
spotify
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# ..                      ...                  ...
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album    Genre  Duration (min)  Tempo (BPM)  \
# 0                      The Landscapes      R&B            3.74        105.4
# 1                        The Archives      R&B            3.82         76.9
# 2          Songs from the Underground      Pop            3.04        130.7
# 3                     The Territories     Rock            3.35        156.7
# 4                        The Chapters     Rock            2.77        153.5
# ..                                ...      ...             ...          ...
# 195                   Chapters Vol. 2     Rock            3.73        152.4
# 196  Songs from the Edge of the World  Hip-Hop            2.88         67.6
# 197                        The Echoes     Rock            4.87        104.3
# 198                   The Territories    Latin            2.60        118.6
# 199  Songs from the Edge of the World      Pop            4.64        103.4
#
#      Energy  Danceability  Loudness (dB)  Popularity  Streams (M)
# 0    0.5390        0.5747          -7.43          52        74.21
# 1    0.4047        0.8809          -6.85          49        15.44
# 2    0.6967        0.7497          -6.25          67       253.67
# 3    0.8623        0.5503          -8.31          72        10.00
# 4    0.7548        0.3262          -2.08          61        90.17
# ..      ...           ...            ...         ...          ...
# 195  0.9308        0.5013          -4.80          59        49.02
# 196  0.7090        0.7991          -5.96          35         0.10
# 197  0.7052        0.4378          -1.00          84       930.03
# 198  0.7875        0.6610          -5.40          72       211.98
# 199  0.7720        0.7726          -4.00          71       195.37
#
# [200 rows x 11 columns]

# %% [markdown]
# ## The precision Option
# - The `display.precision` option sets the number of digits that appears after a decimal point in a floating-point number.
# - The default value is 6.

# %%
spotify.head()
# Out:
#                     Track               Artist                       Album  \
# 0                   Roads   The Midnight Drift              The Landscapes
# 1  The Horizon of Nowhere  Starfall Collective                The Archives
# 2                Sky Away          Sam Kariuki  Songs from the Underground
# 3            Only Sunrise        Andre Laurent             The Territories
# 4                   Storm   The Broken Compass                The Chapters
#
#   Genre  Duration (min)  Tempo (BPM)  Energy  Danceability  Loudness (dB)  \
# 0   R&B            3.74        105.4  0.5390        0.5747          -7.43
# 1   R&B            3.82         76.9  0.4047        0.8809          -6.85
# 2   Pop            3.04        130.7  0.6967        0.7497          -6.25
# 3  Rock            3.35        156.7  0.8623        0.5503          -8.31
# 4  Rock            2.77        153.5  0.7548        0.3262          -2.08
#
#    Popularity  Streams (M)
# 0          52        74.21
# 1          49        15.44
# 2          67       253.67
# 3          72        10.00
# 4          61        90.17

# %%
pd.options.display.precision
# Out:
# 6

# %%
pd.get_option('display.precision')
# Out:
# 6

# %%
pd.options.display.precision = 2

# %%
pd.set_option('display.precision', 2)

# %%
spotify.head()
# Out:
#                     Track               Artist                       Album  \
# 0                   Roads   The Midnight Drift              The Landscapes
# 1  The Horizon of Nowhere  Starfall Collective                The Archives
# 2                Sky Away          Sam Kariuki  Songs from the Underground
# 3            Only Sunrise        Andre Laurent             The Territories
# 4                   Storm   The Broken Compass                The Chapters
#
#   Genre  Duration (min)  Tempo (BPM)  Energy  Danceability  Loudness (dB)  \
# 0   R&B            3.74        105.4    0.54          0.57          -7.43
# 1   R&B            3.82         76.9    0.40          0.88          -6.85
# 2   Pop            3.04        130.7    0.70          0.75          -6.25
# 3  Rock            3.35        156.7    0.86          0.55          -8.31
# 4  Rock            2.77        153.5    0.75          0.33          -2.08
#
#    Popularity  Streams (M)
# 0          52        74.21
# 1          49        15.44
# 2          67       253.67
# 3          72        10.00
# 4          61        90.17

# %%
spotify['Danceability'].iloc[0]
# Out:
# np.float64(0.5747)

# %% [markdown]
# ## Temporary Options with option_context
# - The `pd.option_context` context manager temporarily changes options within a `with` block.
# - Options revert back to their default values when the block ends.
# - Pass a dictionary where the keys are the settings and the values are their temporary values.
# - Use the `display` function to output the `DataFrame`.

# %%
pd.reset_option('display.precision')

# %%
spotify = pd.read_csv('spotify.csv')
spotify.head()
# Out:
#                     Track               Artist                       Album  \
# 0                   Roads   The Midnight Drift              The Landscapes
# 1  The Horizon of Nowhere  Starfall Collective                The Archives
# 2                Sky Away          Sam Kariuki  Songs from the Underground
# 3            Only Sunrise        Andre Laurent             The Territories
# 4                   Storm   The Broken Compass                The Chapters
#
#   Genre  Duration (min)  Tempo (BPM)  Energy  Danceability  Loudness (dB)  \
# 0   R&B            3.74        105.4  0.5390        0.5747          -7.43
# 1   R&B            3.82         76.9  0.4047        0.8809          -6.85
# 2   Pop            3.04        130.7  0.6967        0.7497          -6.25
# 3  Rock            3.35        156.7  0.8623        0.5503          -8.31
# 4  Rock            2.77        153.5  0.7548        0.3262          -2.08
#
#    Popularity  Streams (M)
# 0          52        74.21
# 1          49        15.44
# 2          67       253.67
# 3          72        10.00
# 4          61        90.17

# %%
with pd.option_context({"display.precision": 3, "display.max_columns": 6}):
    display(spotify)
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# ..                      ...                  ...
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album  ... Loudness (dB)  Popularity  \
# 0                      The Landscapes  ...         -7.43          52
# 1                        The Archives  ...         -6.85          49
# 2          Songs from the Underground  ...         -6.25          67
# 3                     The Territories  ...         -8.31          72
# 4                        The Chapters  ...         -2.08          61
# ..                                ...  ...           ...         ...
# 195                   Chapters Vol. 2  ...         -4.80          59
# 196  Songs from the Edge of the World  ...         -5.96          35
# 197                        The Echoes  ...         -1.00          84
# 198                   The Territories  ...         -5.40          72
# 199  Songs from the Edge of the World  ...         -4.00          71
#
#      Streams (M)
# 0          74.21
# 1          15.44
# 2         253.67
# 3          10.00
# 4          90.17
# ..           ...
# 195        49.02
# 196         0.10
# 197       930.03
# 198       211.98
# 199       195.37
#
# [200 rows x 11 columns]

# %%
spotify
# Out:
#                       Track               Artist  \
# 0                     Roads   The Midnight Drift
# 1    The Horizon of Nowhere  Starfall Collective
# 2                  Sky Away          Sam Kariuki
# 3              Only Sunrise        Andre Laurent
# 4                     Storm   The Broken Compass
# ..                      ...                  ...
# 195      Waiting in the Sky          Nina Volkov
# 196             Waves Again          Luna Torres
# 197   The Roads of Tomorrow           Sofia Vega
# 198         Another Sunrise   The Wandering Suns
# 199           Silence Again          Luna Torres
#
#                                 Album    Genre  Duration (min)  Tempo (BPM)  \
# 0                      The Landscapes      R&B            3.74        105.4
# 1                        The Archives      R&B            3.82         76.9
# 2          Songs from the Underground      Pop            3.04        130.7
# 3                     The Territories     Rock            3.35        156.7
# 4                        The Chapters     Rock            2.77        153.5
# ..                                ...      ...             ...          ...
# 195                   Chapters Vol. 2     Rock            3.73        152.4
# 196  Songs from the Edge of the World  Hip-Hop            2.88         67.6
# 197                        The Echoes     Rock            4.87        104.3
# 198                   The Territories    Latin            2.60        118.6
# 199  Songs from the Edge of the World      Pop            4.64        103.4
#
#      Energy  Danceability  Loudness (dB)  Popularity  Streams (M)
# 0    0.5390        0.5747          -7.43          52        74.21
# 1    0.4047        0.8809          -6.85          49        15.44
# 2    0.6967        0.7497          -6.25          67       253.67
# 3    0.8623        0.5503          -8.31          72        10.00
# 4    0.7548        0.3262          -2.08          61        90.17
# ..      ...           ...            ...         ...          ...
# 195  0.9308        0.5013          -4.80          59        49.02
# 196  0.7090        0.7991          -5.96          35         0.10
# 197  0.7052        0.4378          -1.00          84       930.03
# 198  0.7875        0.6610          -5.40          72       211.98
# 199  0.7720        0.7726          -4.00          71       195.37
#
# [200 rows x 11 columns]
